# %% [markdown]
# # 🐙🔮 **Mansion of Madness Puzzle Solver**
#
# ---

# %% [markdown]
# _Summon the latest code incantations and anchor your rituals to the abyssal depths of the repository folder_
#
# ## 1. 🪦 **Cast the environment summon spell**

# %%
#@title _The code whispers in the dark, a warning of things better left unseen_

# Install the PuzzleSolver on the environment:
# %cd
# !export URL='https://github.com/polirritmico/' && export REPO='mansion-madness-puzzle-solver' && rm -rf "$REPO" && git clone "$URL$REPO"
# %cd mansion-madness-puzzle-solver

# --------------------------------------------------
# HACK: Increase Google Colab output font size
from IPython.display import HTML
shell = get_ipython()

def adjust_font_size():
  display(HTML("<style>body {font-size: 13px;}"))

if adjust_font_size not in shell.events.callbacks['pre_execute']:
  shell.events.register('pre_execute', adjust_font_size)

italic_code = "\033[3m"
no_style_code = "\033[0m"
# --------------------------------------------------

from solver import PuzzleSolver

def cast_solver_spell(symbols: tuple[str, ...], seed: int | None = None) -> None:
    solver = PuzzleSolver(symbols, seed)
    solver.solve()

print(
    f"\n{italic_code}The PuzzleSolver has been awakened...\n"
    f"Beware the growing shadow as Cthulhu stirs from the depths.{no_style_code}"
)

# %% [markdown]
# ## 2. 💀 Settings
#
# _Ritual adjustments:_

# %%
symbols = ("g", "y", "b", "r", "w")
chaos_seed = 666 # Change to None for truly random: chaos_seed = None

# %% [markdown]
# ## 3. 🔯 **Run**

# %%
cast_solver_spell(symbols, chaos_seed)
